# %% [markdown]
# <small>
# 1-1. 1개
# 1-2. 8개
# 1-3. 1개
# 1-4. 모든 포화 이진 트리에 대해 성립한다.
# ---
# 2-1. n/2개
# 2-2. 리프노드의 수는 내부 노드의 수에 1을 더한 것과 같다.
# ---
# 3-1. 5,3,1,8,7,6,9
# 3-2. 1,3,5,6,7,8,9
# 3-3. 1,3,6,7,9,8,5
# 3-4. 베이스 케이스 : h=1 T는 단 한개의 루트 노드를 갖는다. 유일한 노드를 방문하는 것은 당연히 정렬된 순서다.
# 귀납적 과정 :  k<h인 모든 k에 대해 성립한다 가정하자.
# 귀납적 전개  :  귀납적 가정에 의해 중위 순회는 각각 왼쪽 서브트리와 오른 쪽 서브트리를 정렬된 순서로 방문하낟. 왼쪽 서브트리의 모든 키는 루트노드의 키보다 작고 오른쪽 서브트리의 모든 키는 루트노드의 키보다 크므로 중위 순회는 왼쪽 서브트리 -> 루트노드 -> 오른쪽 서브트리 순으로 정렬된 순서이다.
# </small>
# ---
# 4. 30이 루트노드인 55보다 작으므로 왼쪽 자식 노드와 비교한다. 왼쪽 자식노드인 15보다 30이 크니 15의 오른쪽 자식노드인 28과 비교한다. 28보다 크니 28의 오른쪽 자식노드와 비교한다. 30과 동일한 노드를 찾았다. 검색 종료.
# ---
# 5. ![KakaoTalk_20260415_204803777.jpg]([Media removed: image/jpeg, ~221112 chars])
# ---
# 6. ![image.png]([Media removed: image/png, ~330096 chars])
# ---
# 7.![image.png]([Media removed: image/png, ~338248 chars])
# ---
# 8. ![image.png]([Media removed: image/png, ~332384 chars])
# ---
# 9. 최대 높이 : n 최소 높이 : log n
